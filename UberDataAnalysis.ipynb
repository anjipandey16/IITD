# %%
import pandas as pd
from xarray.computation.ops import fillna

uber_data = pd.read_csv('C:\\Users\\Anjali\\Desktop\\AI_Course\\MIT\\1.AILanscape\\UberCaseStudy.csv', engine='python')
#uber_data.plot(figsize=(15, 5))
#uber_data.plot.scatter(y='pickups',x='spd', alpha=0.5, figsize=(15, 5))
#uber_data.size
uber_data.info()
#uber_data.head()
#uber_data.describe()

#uber_data.nunique()
#uber_data.plot.area(subplots=True,figsize=(15,5))
uber_data.duplicated().sum()
uber_data['temp'].fillna(uber_data['temp'].median(),inplace=True)
uber_data['borough'].fillna(uber_data['borough'].mode()[0], inplace=True)

uber_data['pickup_hour'] = pd.to_datetime(uber_data['pickup_dt'],format='%d-%m-%Y %H:%M').dt.hour
uber_data['pickup_day'] = pd.to_datetime(uber_data['pickup_dt'],format='%d-%m-%Y %H:%M').dt.day
uber_data.head()
#uber_data.duplicated().sum()
uber_data.groupby['pickups'].sum().sort_values(ascending=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29101 entries, 0 to 29100
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pickup_dt  29101 non-null  object
#  1   borough    26058 non-null  object
#  2   pickups    29101 non-null  int64
#  3   spd        29101 non-null  float64
#  4   vsb        29101 non-null  float64
#  5   temp       28742 non-null  float64
#  6   dewp       29101 non-null  float64
#  7   slp        29101 non-null  float64
#  8   pcp01      29101 non-null  float64
#  9   pcp06      29101 non-null  float64
#  10  pcp24      29101 non-null  float64
#  11  sd         29101 non-null  float64
#  12  hday       29101 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 2.9+ MB
# ...
